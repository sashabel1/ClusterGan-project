# %% [markdown]
# <a href="https://colab.research.google.com/github/sashabel1/ClusterGan-project/blob/main/CLUSTERGANTRY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/lvyufeng/MindSpore-GAN
# Out:
# Cloning into 'MindSpore-GAN'...
# remote: Enumerating objects: 153, done.
# remote: Counting objects: 100% (153/153), done.
# remote: Compressing objects: 100% (103/103), done.
# remote: Total 153 (delta 74), reused 119 (delta 42), pack-reused 0 (from 0)
# Receiving objects: 100% (153/153), 1.52 MiB | 6.85 MiB/s, done.
# Resolving deltas: 100% (74/74), done.

# %%
# %cd MindSpore-GAN/
# Out:
# [Errno 2] No such file or directory: 'MindSpore-GAN/'
# /content/MindSpore-GAN

# %%
# !pip install -r requirements.txt

# %%
# !bash scripts/download_mnist.sh
# Out:
# --2025-05-13 08:52:18--  http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Resolving yann.lecun.com (yann.lecun.com)... 15.204.224.156
# Connecting to yann.lecun.com (yann.lecun.com)|15.204.224.156|:80... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-05-13 08:52:18 ERROR 404: Not Found.
#
# --2025-05-13 08:52:18--  http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Resolving yann.lecun.com (yann.lecun.com)... 15.204.224.156
# Connecting to yann.lecun.com (yann.lecun.com)|15.204.224.156|:80... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-05-13 08:52:18 ERROR 404: Not Found.
#
# --2025-05-13 08:52:18--  http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Resolving yann.lecun.com (yann.lecun.com)... 15.204.224.156
# Connecting to yann.lecun.com (yann.lecun.com)|15.204.224.156|:80... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-05-13 08:52:18 ERROR 404: Not Found.
#
# ...

# %%
# %cd src/clustergan/
# Out:
# /content/MindSpore-GAN/src/clustergan

# %%
# !pip install mindspore
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 962.0/962.0 MB 994.9 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 76.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# ...

# %%
# !python3 clustergan.py
# Out:
# [WARNING] ME(4050:22160558297088,MainProcess):2025-05-13-09:03:39.472.000 [mindspore/common/api.py:1109] 'mindspore.ms_function' will be deprecated and removed in a future version. Please use 'mindspore.jit' instead.
# [WARNING] ME(4050:22160558297088,MainProcess):2025-05-13-09:03:39.472.000 [mindspore/common/api.py:1109] 'mindspore.ms_function' will be deprecated and removed in a future version. Please use 'mindspore.jit' instead.
# [WARNING] ME(4050:22160558297088,MainProcess):2025-05-13-09:03:39.472.000 [mindspore/dataset/core/validator_helpers.py:744] 'Rescale' from mindspore.dataset.vision.c_transforms is deprecated from version 1.8 and will be removed in a future version. Use 'Rescale' from mindspore.dataset.vision instead.
# ...
