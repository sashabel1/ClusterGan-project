# %% [markdown]
# <a href="https://colab.research.google.com/github/sashabel1/ClusterGan-project/blob/main/CLusters.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/eriklindernoren/PyTorch-GAN.git
# %cd PyTorch-GAN
# Out:
# Cloning into 'PyTorch-GAN'...
# remote: Enumerating objects: 1283, done.
# remote: Total 1283 (delta 0), reused 0 (delta 0), pack-reused 1283 (from 1)
# Receiving objects: 100% (1283/1283), 68.04 MiB | 30.15 MiB/s, done.
# Resolving deltas: 100% (751/751), done.
# /content/PyTorch-GAN

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 103.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 81.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 89.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
# %cd /content/PyTorch-GAN/implementations/
# Out:
# /content/PyTorch-GAN/implementations

# %% [markdown]
# ACGAN

# %%
# %cd /content/PyTorch-GAN/implementations/acgan/
# !python3 acgan.py
# Out:
# /content/PyTorch-GAN/implementations/acgan
# Namespace(n_epochs=200, batch_size=64, lr=0.0002, b1=0.5, b2=0.999, n_cpu=8, latent_dim=100, n_classes=10, img_size=32, channels=1, sample_interval=400)
# 100% 9.91M/9.91M [00:00<00:00, 38.4MB/s]
# 100% 28.9k/28.9k [00:00<00:00, 1.11MB/s]
# 100% 1.65M/1.65M [00:00<00:00, 10.6MB/s]
# 100% 4.54k/4.54k [00:00<00:00, 10.7MB/s]
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1739: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)
# [Epoch 0/200] [Batch 0/938] [D loss: 1.497651, acc: 6%] [G loss: 1.497374]
# [Epoch 0/200] [Batch 1/938] [D loss: 1.497711, acc: 13%] [G loss: 1.497480]
# [Epoch 0/200] [Batch 2/938] [D loss: 1.497813, acc: 8%] [G loss: 1.497625]
# [Epoch 0/200] [Batch 3/938] [D loss: 1.497897, acc: 7%] [G loss: 1.497835]
# [Epoch 0/200] [Batch 4/938] [D loss: 1.497933, acc: 6%] [G loss: 1.497844]
# ...

# %% [markdown]
# הדפסת התמונות שנוצרו ע"י האלגוריתם למעלה

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os

image_folder = 'images'
image_files = os.listdir(image_folder)
fig, axes = plt.subplots(1, len(image_files), figsize=(15, 15))

# אם יש רק עמודה אחת, axes לא יהיה iterable
if len(image_files) == 1:
    axes = [axes]

for ax, img_file in zip(axes, image_files):
    img_path = os.path.join(image_folder, img_file)
    img = mpimg.imread(img_path)
    ax.imshow(img)
    ax.axis('off')

plt.show()

# %% [markdown]
# AAE

# %%
# %cd /content/PyTorch-GAN//implementations/aae
# Out:
# /content/PyTorch-GAN/implementations/aae

# %%
# !python3 aae.py
# Out:
# Namespace(n_epochs=200, batch_size=64, lr=0.0002, b1=0.5, b2=0.999, n_cpu=8, latent_dim=10, img_size=32, channels=1, sample_interval=400)
# [Epoch 0/200] [Batch 0/938] [D loss: 0.698517] [G loss: 0.923278]
# [Epoch 0/200] [Batch 1/938] [D loss: 0.692834] [G loss: 0.905924]
# [Epoch 0/200] [Batch 2/938] [D loss: 0.684593] [G loss: 0.884372]
# [Epoch 0/200] [Batch 3/938] [D loss: 0.674805] [G loss: 0.860457]
# [Epoch 0/200] [Batch 4/938] [D loss: 0.677104] [G loss: 0.841052]
# [Epoch 0/200] [Batch 5/938] [D loss: 0.667578] [G loss: 0.815507]
# [Epoch 0/200] [Batch 6/938] [D loss: 0.664104] [G loss: 0.796903]
# [Epoch 0/200] [Batch 7/938] [D loss: 0.663175] [G loss: 0.775906]
# [Epoch 0/200] [Batch 8/938] [D loss: 0.647622] [G loss: 0.750619]
# [Epoch 0/200] [Batch 9/938] [D loss: 0.646622] [G loss: 0.724834]
# [Epoch 0/200] [Batch 10/938] [D loss: 0.651026] [G loss: 0.705148]
# [Epoch 0/200] [Batch 11/938] [D loss: 0.635562] [G loss: 0.680541]
# ...

# %% [markdown]
# Display the generated images

# %%
import matplotlib.pyplot as plt
import os
from PIL import Image

image_dir = "images"
image_files = sorted([f for f in os.listdir(image_dir) if f.endswith('.png')])

# Display the last 5 generated image samples
for fname in image_files[-5:]:
    img = Image.open(os.path.join(image_dir, fname))
    plt.figure(figsize=(6, 6))
    plt.title(f"Generated Image - {fname}")
    plt.imshow(img)
    plt.axis("off")
    plt.show()

# %% [markdown]
# Compare real images with generated - need to try work on this

# %% [markdown]
# BAGAN

# %%
# %cd /content/PyTorch-GAN/implementations/began
# Out:
# /content/PyTorch-GAN/implementations/began

# %%
# !python3 began.py
# Out:
# Namespace(n_epochs=200, batch_size=64, lr=0.0002, b1=0.5, b2=0.999, n_cpu=8, latent_dim=62, img_size=32, channels=1, sample_interval=400)
# Traceback (most recent call last):
#   File "/content/PyTorch-GAN/implementations/began/began.py", line 196, in <module>
#     M = (d_loss_real + torch.abs(diff)).data[0]
#         ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^
# IndexError: invalid index of a 0-dim tensor. Use `tensor.item()` in Python or `tensor.item<T>()` in C++ to convert a 0-dim tensor to a number

# %% [markdown]
# Display the generated images- check if this is okey

# %%
import matplotlib.pyplot as plt
import os
from PIL import Image

image_dir = "images"

image_files = sorted([f for f in os.listdir(image_dir) if f.endswith('.png')])

# הצגת חמש התמונות האחרונות שנוצרו
for fname in image_files[-5:]:
    img = Image.open(os.path.join(image_dir, fname))  # פתיחת התמונה
    plt.figure(figsize=(6, 6))  # יצירת גרף עם גודל מסך מותאם
    plt.title(f"Generated Image - {fname}")  # כותרת התמונה
    plt.imshow(img)  # הצגת התמונה
    plt.axis("off")  # הסרת הצירים
    plt.show()  # הצגת התמונה
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-23-0e335cab1ec6> in <cell line: 0>()
#       5 image_dir = "images"
#       6
# ----> 7 image_files = sorted([f for f in os.listdir(image_dir) if f.endswith('.png')])
#       8
#       9 # הצגת חמש התמונות האחרונות שנוצרו
#
# FileNotFoundError: [Errno 2] No such file or directory: 'images'

# %% [markdown]
# BicycleGAN -not woeking, problem with the data set

# %% [markdown]
# הורדה של הדטה סט

# %%
#!mv /content/PyTorch-GAN/implementations/bicyclegan/datasets.py /content/PyTorch-GAN/implementations/bicyclegan/datasets_custom.py

# %%
#import os
#os.makedirs('/root/.kaggle', exist_ok=True)
#!cp kaggle.json /root/.kaggle/
#!chmod 600 /root/.kaggle/kaggle.json

# %%
#!kaggle datasets download -d balraj98/edges2shoes-dataset

# %%
#!unzip /content/PyTorch-GAN/implementations/bicyclegan/edges2shoes-dataset.zip -d /content/PyTorch-GAN/data/edges2shoes

# %%
#!ls /content/PyTorch-GAN/data/edges2shoes

# %%
#pip install --upgrade datasets torchvision

# %%
#pip install mpmath==1.2.1

# %%
#!cd /content/PyTorch-GAN/implementations/bicyclegan/ && python bicyclegan.py --dataset edges2shoes

# %% [markdown]
# Boundary-Seeking GAN

# %%
# %cd /content/PyTorch-GAN/implementations/bgan/
# !python3 bgan.py
# Out:
# Streaming output truncated to the last 5000 lines.
# [Epoch 7/200] [Batch 154/938] [D loss: 0.194227] [G loss: 1.379334]
# [Epoch 7/200] [Batch 155/938] [D loss: 0.197287] [G loss: 1.800624]
# [Epoch 7/200] [Batch 156/938] [D loss: 0.262143] [G loss: 1.466096]
# [Epoch 7/200] [Batch 157/938] [D loss: 0.258859] [G loss: 0.511019]
# [Epoch 7/200] [Batch 158/938] [D loss: 0.384348] [G loss: 6.110240]
# [Epoch 7/200] [Batch 159/938] [D loss: 0.447405] [G loss: 0.232769]
# [Epoch 7/200] [Batch 160/938] [D loss: 0.689187] [G loss: 12.852074]
# [Epoch 7/200] [Batch 161/938] [D loss: 0.306896] [G loss: 0.221216]
# [Epoch 7/200] [Batch 162/938] [D loss: 0.222280] [G loss: 4.774939]
# [Epoch 7/200] [Batch 163/938] [D loss: 0.173700] [G loss: 1.709618]
# [Epoch 7/200] [Batch 164/938] [D loss: 0.242282] [G loss: 1.068434]
# [Epoch 7/200] [Batch 165/938] [D loss: 0.284857] [G loss: 2.069163]
# [Epoch 7/200] [Batch 166/938] [D loss: 0.216009] [G loss: 0.721203]
# ...

# %% [markdown]
# Display the generated pictures

# %%
import os
from IPython.display import Image, display

# מציג את כל התמונות מהתיקייה "images", לפי הסדר
image_folder = "images"
image_files = sorted([f for f in os.listdir(image_folder) if f.endswith(".png")], key=lambda x: int(x.split('.')[0]))

for image_file in image_files:
    display(Image(filename=os.path.join(image_folder, image_file)))
